# %% [markdown]
# <a href="https://colab.research.google.com/github/Lakshmi-Sayyapureddy1819/Oralvis__Assignment1/blob/main/Assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Install ultralytics YOLO package and other dependencies
# !pip install -q ultralytics
# !pip install -q numpy

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
import random
import shutil

def split_dataset(img_dir, lbl_dir, output_dir, train_ratio=0.8, val_ratio=0.1, test_ratio=0.1):
    assert abs(train_ratio + val_ratio + test_ratio - 1.0) < 1e-6, "Ratios must sum to 1."
    os.makedirs(output_dir, exist_ok=True)

    img_files = [f for f in os.listdir(img_dir) if f.endswith('.jpg')]
    random.shuffle(img_files)
    n = len(img_files)

    train_end = int(train_ratio * n)
    val_end = train_end + int(val_ratio * n)

    splits = {
        'train': img_files[:train_end],
        'val': img_files[train_end:val_end],
        'test': img_files[val_end:]
    }

    for split, files in splits.items():
        img_out = os.path.join(output_dir, split, 'images')
        lbl_out = os.path.join(output_dir, split, 'labels')
        os.makedirs(img_out, exist_ok=True)
        os.makedirs(lbl_out, exist_ok=True)

        for file in files:
            lbl_file = file.replace('.jpg', '.txt')
            shutil.copy(os.path.join(img_dir, file), os.path.join(img_out, file))
            shutil.copy(os.path.join(lbl_dir, lbl_file), os.path.join(lbl_out, lbl_file))

# Define paths (update according to your Drive path)
IMG_DIR = '/content/drive/MyDrive/OralVis (1)/images'
LBL_DIR = '/content/drive/MyDrive/OralVis (1)/labels'
OUT_DIR = '/content/drive/MyDrive/OralVis (1)/data'

split_dataset(IMG_DIR, LBL_DIR, OUT_DIR)
print("Dataset split completed.")
# Out:
# Dataset split completed.

# %%
ls
# Out:
# '2025-04-25 23-15-32.mkv'
#  AD.zip
# 'ai ml'/
#  Assignment.ipynb
#  assignment.mp4
#  best_pro_mern/
# 'Blackcoffer (2).zip'
#  Blackcoffer.zip
# 'Colab Notebooks'/
#  CO.zip
#  dataset/
# 'dont give gap betwwen transetoct and give theis i....gsheet'
#  Downloads12.zip
# 'example of flow of execution .gdoc'
# 'explaination of walmart current implementation of our product.gdoc'
#  final_dataset/
# 'Founder-Investor Matching AI Model.zip'
# 'give all long answer 10 m solution long and brief... (1).gdoc'
# 'give all long answer 10 m solution long and brief....gdoc'
# 'import React, { useState } from '\''react'\'''$'\n''import {....gdoc'
# 'i need all this and previous output in a doc file....gdoc'
# 'i need to extract the image that are present as t....gsheet'
# ' Investor Fund Profile Data Extraction Agent.gdoc'
#  Investor-Outreach-Email-Scheduling-System/
# 'its a hackathom for problem statemet say as theme....gdoc'
# 'i wnat to make the video in 2 mins.gdoc'
# ...

# %%
cd  /content/drive/MyDrive/OralVis (1)
# Out:
# /content/drive/MyDrive/OralVis (1)

# %%
data_yaml = """
train: /content/drive/MyDrive/OralVis (1)/data/train/images
val: /content/drive/MyDrive/OralVis (1)/data/val/images
test: /content/drive/MyDrive/OralVis (1)/data/test/images
names:
  0: Canine (13)
  1: Canine (23)
  2: Canine (33)
  3: Canine (43)
  4: Central Incisor (21)
  5: Central Incisor (41)
  6: Central Incisor (31)
  7: Central Incisor (11)
  8: First Molar (16)
  9: First Molar (26)
  10: First Molar (36)
  11: First Molar (46)
  12: First Premolar (14)
  13: First Premolar (34)
  14: First Premolar (44)
  15: First Premolar (24)
  16: Lateral Incisor (22)
  17: Lateral Incisor (32)
  18: Lateral Incisor (42)
  19: Lateral Incisor (12)
  20: Second Molar (17)
  21: Second Molar (27)
  22: Second Molar (37)
  23: Second Molar (47)
  24: Second Premolar (15)
  25: Second Premolar (25)
  26: Second Premolar (35)
  27: Second Premolar (45)
  28: Third Molar (18)
  29: Third Molar (28)
  30: Third Molar (38)
  31: Third Molar (48)
"""

with open('/content/drive/MyDrive/OralVis (1)/data/data.yaml', 'w') as f:
    f.write(data_yaml)

print("data.yaml created.")
# Out:
# data.yaml created.

# %%
from ultralytics import YOLO

# Load pretrained YOLOv8s model
model = YOLO("yolov8s.pt")

# Train the model
results = model.train(
    data='/content/drive/MyDrive/OralVis (1)/data/data.yaml',
    epochs=100,
    imgsz=640,
    batch=16,
    name='OralVis_Tooth_Numbering',
    device=0  # '0' for GPU, use 'cpu' if no GPU
)
print("Training complete.")
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...
# Ultralytics 8.3.190 🚀 Python-3.12.11 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
# Validate the model (prints metrics like precision, recall, mAP)
metrics = model.val()
print(metrics)

# Predict bounding boxes on test images and save results
predictions = model.predict(source='/content/drive/MyDrive/OralVis (1)/data/test/images', save=True, conf=0.25)

print("Predictions saved.")
# Out:
# Ultralytics 8.3.190 🚀 Python-3.12.11 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# Model summary (fused): 72 layers, 11,137,968 parameters, 0 gradients, 28.5 GFLOPs
# val: Fast image access ✅ (ping: 0.4±0.1 ms, read: 28.3±11.2 MB/s, size: 72.4 KB)
# val: Scanning /content/drive/MyDrive/OralVis (1)/data/val/labels.cache... 64 images, 1 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 64/64 81865.0it/s 0.0s
# WARNING ⚠️ Box and segment counts should be equal, but got len(segments) = 33, len(boxes) = 1752. To resolve this only boxes will be used and all segments will be removed. To avoid this please supply either a detect or segment dataset, not a detect-segment mixed dataset.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 0.78it/s 5.1s
#                    all         64       1752      0.937       0.95      0.965      0.787
#            Canine (13)         57         57      0.943       0.93      0.969      0.782
# ...
